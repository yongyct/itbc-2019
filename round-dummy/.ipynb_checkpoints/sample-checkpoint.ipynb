# %%
import pandas as pd

# %%
df = pd.read_csv('data/Dummy data.csv')

# %%
df.loc[:, 'number'] = df.loc[:, 'number'] + 1
# Out:
#       id  number
# 0      0       2
# 1      1       3
# 2      2       4
# 3      3       5
# 4      4       6
# ..   ...     ...
# 96    96      98
# 97    97      99
# 98    98     100
# 99    99     101
# 100  100     102
#
# [101 rows x 2 columns]

# %%
df.to_csv('submission.csv', index=False)

# %%
results_df = pd.read_csv('submission.csv')
results_df
# Out:
#       id  number
# 0      0       2
# 1      1       3
# 2      2       4
# 3      3       5
# 4      4       6
# ..   ...     ...
# 96    96      98
# 97    97      99
# 98    98     100
# 99    99     101
# 100  100     102
#
# [101 rows x 2 columns]
